# %%
### document structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the content of the document.",
    metadata={"source": "generated", "author": "langchain"},
)
doc
# Out:
# Document(metadata={'source': 'generated', 'author': 'langchain'}, page_content='This is the content of the document.')

# %%
import os
os.makedirs('data/text_files', exist_ok=True)

# %%
sample_texts = {
    "data/text_files/doc1.txt": """ Python is a high-level, interpreted programming language known for its readability and versatility. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python's extensive standard library and vibrant ecosystem of third-party packages make it a popular choice for web development, data analysis, artificial intelligence, scientific computing, and more.""",
}

for filepath, content in sample_texts.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)

print("Sample text files created.")
# Out:
# Sample text files created.

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("data/text_files/doc1.txt", encoding="utf-8")
documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'source': 'data/text_files/doc1.txt'}, page_content=" Python is a high-level, interpreted programming language known for its readability and versatility. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python's extensive standard library and vibrant ecosystem of third-party packages make it a popular choice for web development, data analysis, artificial intelligence, scientific computing, and more.")]

# %%
from langchain_community.document_loaders import PyMuPDFLoader, PyPDFLoader
from langchain_community.document_loaders import DirectoryLoader
DIR_LOADER = DirectoryLoader(
    "data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    # loader_kwargs={'encoding': 'utf-8'},
    show_progress=False
)

pdf_direactory = DIR_LOADER.load()
print(pdf_direactory)
# Out:
# [Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'data\\pdf\\1758773206507.pdf', 'file_path': 'data\\pdf\\1758773206507.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-09-25T04:06:03+00:00', 'trapped': '', 'modDate': 'D:20250925040603Z', 'creationDate': '', 'page': 0}, page_content=''), Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'data\\pdf\\1758773206507.pdf', 'file_path': 'data\\pdf\\1758773206507.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-09-25T04:06:03+00:00', 'trapped': '', 'modDate': 'D:20250925040603Z', 'creationDate': '', 'page': 1}, page_content=''), Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'data\\pdf\\1758773206507.pdf', 'file_path': 'data\\pdf\\1758773206507.pdf', 'total_pages': 7, 'format': 'PDF 1
# ...
